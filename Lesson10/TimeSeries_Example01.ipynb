# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import requests
from io import StringIO
import matplotlib.pyplot as plt

# %%
#Defining location of dataset 
filepath="/opt/datasets/ist652/Crimes/crimes_2018_2021.csv"

# %%
crimes=pd.read_csv(filepath)
crimes.head()
# Out:
#          ID Case Number              Date                  Block  IUCR  \
# 0  11646166    JC213529     9/1/2018 0:01  082XX S INGLESIDE AVE   810
# 1  11645648    JC212959     1/1/2018 8:00    024XX N MONITOR AVE  1153
# 2  11645959    JC211511  12/20/2018 16:00     045XX N ALBANY AVE  2820
# 3  11645557    JC212685     4/1/2018 0:01     080XX S VERNON AVE  1153
# 4  11646293    JC213749  12/20/2018 15:00   023XX N LOCKWOOD AVE  1154
#
#          Primary Type                              Description  \
# 0               THEFT                                OVER $500
# 1  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2       OTHER OFFENSE                         TELEPHONE THREAT
# 3  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False      True  ...   8.0            44.0         6
# 1            RESIDENCE   False     False  ...  30.0            19.0        11
# 2            RESIDENCE   False     False  ...  33.0            14.0       08A
# 3            RESIDENCE   False     False  ...   6.0            44.0        11
# 4            APARTMENT   False     False  ...  36.0            19.0        11
#
#    X Coordinate Y Coordinate  Year      Updated On  Latitude Longitude  \
# 0           NaN          NaN  2018  4/6/2019 16:04       NaN       NaN
# 1           NaN          NaN  2018  4/6/2019 16:04       NaN       NaN
# 2           NaN          NaN  2018  4/6/2019 16:04       NaN       NaN
# 3           NaN          NaN  2018  4/6/2019 16:04       NaN       NaN
# 4           NaN          NaN  2018  4/6/2019 16:04       NaN       NaN
#
#    Location
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 22 columns]

# %%
crimes.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %% [markdown]
# ### Dataset description and data dictionary (the data used in this notebook starts in 2018, not 2001):
#
# https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2

# %% [markdown]
# ##### Explanation of code below
# - Line 1 Converts the "Date" column in the crimes DataFrame to a pandas datetime format.
# - Line 2 - Sets the "Date" column as the index of the DataFrame.
# - Line 3 Displays the first five rows of the DataFrame

# %%
#We have a column with timestamps (the "Date" column). We will convert that column to dates that pandas
#can understand and use it as our index. (It takes a while to complete the conversion.. be patient)
crimes["Date"]=pd.to_datetime(crimes["Date"])
crimes.set_index("Date",inplace=True)
crimes.head()
# Out:
#                            ID Case Number                  Block  IUCR  \
# Date
# 2018-09-01 00:01:00  11646166    JC213529  082XX S INGLESIDE AVE   810
# 2018-01-01 08:00:00  11645648    JC212959    024XX N MONITOR AVE  1153
# 2018-12-20 16:00:00  11645959    JC211511     045XX N ALBANY AVE  2820
# 2018-04-01 00:01:00  11645557    JC212685     080XX S VERNON AVE  1153
# 2018-12-20 15:00:00  11646293    JC213749   023XX N LOCKWOOD AVE  1154
#
#                            Primary Type  \
# Date
# 2018-09-01 00:01:00               THEFT
# 2018-01-01 08:00:00  DECEPTIVE PRACTICE
# 2018-12-20 16:00:00       OTHER OFFENSE
# 2018-04-01 00:01:00  DECEPTIVE PRACTICE
# 2018-12-20 15:00:00  DECEPTIVE PRACTICE
#
#                                                  Description  \
# Date
# 2018-09-01 00:01:00                                OVER $500
# 2018-01-01 08:00:00      FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-12-20 16:00:00                         TELEPHONE THREAT
# 2018-04-01 00:01:00      FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-12-20 15:00:00  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#                     Location Description  Arrest  Domestic  Beat  ...  Ward  \
# Date                                                              ...
# 2018-09-01 00:01:00            RESIDENCE   False      True   631  ...   8.0
# 2018-01-01 08:00:00            RESIDENCE   False     False  2515  ...  30.0
# 2018-12-20 16:00:00            RESIDENCE   False     False  1724  ...  33.0
# 2018-04-01 00:01:00            RESIDENCE   False     False   631  ...   6.0
# 2018-12-20 15:00:00            APARTMENT   False     False  2515  ...  36.0
#
#                      Community Area  FBI Code X Coordinate  Y Coordinate  \
# Date
# 2018-09-01 00:01:00            44.0         6          NaN           NaN
# 2018-01-01 08:00:00            19.0        11          NaN           NaN
# 2018-12-20 16:00:00            14.0       08A          NaN           NaN
# 2018-04-01 00:01:00            44.0        11          NaN           NaN
# 2018-12-20 15:00:00            19.0        11          NaN           NaN
#
#                      Year      Updated On Latitude  Longitude  Location
# Date
# 2018-09-01 00:01:00  2018  4/6/2019 16:04      NaN        NaN       NaN
# 2018-01-01 08:00:00  2018  4/6/2019 16:04      NaN        NaN       NaN
# 2018-12-20 16:00:00  2018  4/6/2019 16:04      NaN        NaN       NaN
# 2018-04-01 00:01:00  2018  4/6/2019 16:04      NaN        NaN       NaN
# 2018-12-20 15:00:00  2018  4/6/2019 16:04      NaN        NaN       NaN
#
# [5 rows x 21 columns]

# %%
#Could also the following command to adjust the date and index transformations as the dataset was being loaded
#crimes=pd.read_csv(filepath,parse_dates=[2], index_col=[2])

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 946893 entries, 2018-09-01 00:01:00 to 2021-10-01 10:00:00
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    946893 non-null  int64
#  1   Case Number           946893 non-null  object
#  2   Block                 946893 non-null  object
#  3   IUCR                  946893 non-null  object
#  4   Primary Type          946893 non-null  object
#  5   Description           946893 non-null  object
#  6   Location Description  942727 non-null  object
#  7   Arrest                946893 non-null  bool
#  8   Domestic              946893 non-null  bool
#  9   Beat                  946893 non-null  int64
#  10  District              946893 non-null  int64
#  11  Ward                  946854 non-null  float64
#  12  Community Area        946892 non-null  float64
#  13  FBI Code              946893 non-null  object
#  14  X Coordinate          934034 non-null  float64
#  15  Y Coordinate          934034 non-null  float64
#  16  Year                  946893 non-null  int64
#  17  Updated On            946893 non-null  object
#  18  Latitude              934034 non-null  float64
#  19  Longitude             934034 non-null  float64
#  20  Location              934034 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(9)
# memory usage: 146.3+ MB

# %% [markdown]
# ### Resample the DataFrame by day
#
# - Resample the 'Primary Type' column on a daily basis and counts the number of crimes for each day.
# - Sort the resulting Series by its index, which is assumed to be the date

# %%
daily_crimes = crimes['Primary Type'].resample('D').count()  #resample, count crimes per day
daily_crimes.sort_index(inplace=True) # sort by date

# %%
#Dataset contains the crime data from January 2018 to February 2021
daily_crimes.head()
#daily_crimes.tail()
# Out:
# Date
# 2018-01-01    925
# 2018-01-02    560
# 2018-01-03    574
# 2018-01-04    602
# 2018-01-05    664
# Freq: D, Name: Primary Type, dtype: int64

# %%
#We will work just with the 2018 data
daily_crimes2018 = daily_crimes['2018']
daily_crimes2018.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Let's bring in the 2018 daily weather (Temperature) data

# %%
weather_file_path = 'chicago_2018_weather.csv'

# parsing weather data and making the dates column the index
weather2018 = pd.read_csv(weather_file_path, index_col=5, parse_dates=True) # Set the 6th column (index 5) as the index of the DataFrame.
weather2018.head()
# Out:
#                 STATION                             NAME  LATITUDE  LONGITUDE  \
# DATE
# 2018-01-01  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-02  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-03  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-04  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-05  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
#
#             ELEVATION  TMAX  TMIN  TOBS
# DATE
# 2018-01-01      177.7     6  -5.0    -3
# 2018-01-02      177.7     8  -7.0     8
# 2018-01-03      177.7    18   8.0     9
# 2018-01-04      177.7    14   4.0     7
# 2018-01-05      177.7    13   3.0     8

# %%
#Exploring the weather data.... what's wrong ??
weather2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 361 entries, 2018-01-01 to 2018-12-31
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    361 non-null    object
#  1   NAME       361 non-null    object
#  2   LATITUDE   361 non-null    float64
#  3   LONGITUDE  361 non-null    float64
#  4   ELEVATION  361 non-null    float64
#  5   TMAX       361 non-null    int64
#  6   TMIN       360 non-null    float64
#  7   TOBS       361 non-null    int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 25.4+ KB

# %%
#Let's add the median temperature, since we don't have the "Average" temperature in the data
medianTemp=((weather2018.TMAX + weather2018.TMIN)/2)
medianTemp.head()
type(medianTemp)
# Out:
# pandas.core.series.Series

# %%
#Adding a new column of data to the dataframe. There are several ways to do this.
weather2018['medianT']=medianTemp
weather2018.head()
# Out:
#                 STATION                             NAME  LATITUDE  LONGITUDE  \
# DATE
# 2018-01-01  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-02  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-03  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-04  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-01-05  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
#
#             ELEVATION  TMAX  TMIN  TOBS  medianT
# DATE
# 2018-01-01      177.7     6  -5.0    -3      0.5
# 2018-01-02      177.7     8  -7.0     8      0.5
# 2018-01-03      177.7    18   8.0     9     13.0
# 2018-01-04      177.7    14   4.0     7      9.0
# 2018-01-05      177.7    13   3.0     8      8.0

# %%
#Are there missing values?
weather2018.isna().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# TMAX         0
# TMIN         1
# TOBS         0
# medianT      1
# dtype: int64

# %% [markdown]
# We need to handle missing values AND missing items in the time series (361 of 365 days reported)

# %%
#Resample data so ALL days of the year are listed. Use ffill to fill the information for missing days.
weather2018=weather2018.resample('D').ffill()

# %%
weather2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2018-01-01 to 2018-12-31
# Freq: D
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    365 non-null    object
#  1   NAME       365 non-null    object
#  2   LATITUDE   365 non-null    float64
#  3   LONGITUDE  365 non-null    float64
#  4   ELEVATION  365 non-null    float64
#  5   TMAX       365 non-null    int64
#  6   TMIN       364 non-null    float64
#  7   TOBS       365 non-null    int64
#  8   medianT    364 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 28.5+ KB

# %%
# Finding the missing values
weather2018[weather2018.TMIN.isnull()]
# Out:
#                 STATION                             NAME  LATITUDE  LONGITUDE  \
# DATE
# 2018-05-30  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
#
#             ELEVATION  TMAX  TMIN  TOBS  medianT
# DATE
# 2018-05-30      177.7    77   NaN    73      NaN

# %%
weather2018.TMIN.fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_516/2597199767.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather2018.TMIN.fillna(method='ffill',inplace=True)

# %%
weather2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2018-01-01 to 2018-12-31
# Freq: D
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    365 non-null    object
#  1   NAME       365 non-null    object
#  2   LATITUDE   365 non-null    float64
#  3   LONGITUDE  365 non-null    float64
#  4   ELEVATION  365 non-null    float64
#  5   TMAX       365 non-null    int64
#  6   TMIN       365 non-null    float64
#  7   TOBS       365 non-null    int64
#  8   medianT    364 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 28.5+ KB

# %%
weather2018.loc['2018-05']
# Out:
#                 STATION                             NAME  LATITUDE  LONGITUDE  \
# DATE
# 2018-05-01  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-02  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-03  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-04  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-05  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-06  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-07  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-08  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-09  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-10  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-11  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-12  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-13  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-14  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-15  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-16  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-17  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-18  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-19  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-20  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-21  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-22  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-23  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-24  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-25  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-26  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-27  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-28  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-29  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-30  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
# 2018-05-31  USC00111550  CHICAGO NORTHERLY ISLAND, IL US   41.8558   -87.6094
#
#             ELEVATION  TMAX  TMIN  TOBS  medianT
# DATE
# 2018-05-01      177.7    83  59.0    73     71.0
# 2018-05-02      177.7    86  53.0    64     69.5
# 2018-05-03      177.7    67  44.0    66     55.5
# 2018-05-04      177.7    73  58.0    66     65.5
# 2018-05-05      177.7    81  51.0    51     66.0
# 2018-05-06      177.7    60  48.0    51     54.0
# 2018-05-07      177.7    64  47.0    64     55.5
# 2018-05-08      177.7    76  58.0    60     67.0
# 2018-05-09      177.7    82  56.0    65     69.0
# 2018-05-10      177.7    65  46.0    46     55.5
# 2018-05-11      177.7    51  45.0    46     48.0
# 2018-05-12      177.7    48  43.0    47     45.5
# 2018-05-13      177.7    53  45.0    49     49.0
# 2018-05-14      177.7    83  48.0    62     65.5
# 2018-05-15      177.7    64  48.0    49     56.0
# 2018-05-16      177.7    67  49.0    57     58.0
# 2018-05-17      177.7    62  48.0    52     55.0
# 2018-05-18      177.7    55  50.0    53     52.5
# 2018-05-19      177.7    56  51.0    51     53.5
# 2018-05-20      177.7    51  43.0    46     47.0
# 2018-05-21      177.7    58  46.0    51     52.0
# 2018-05-22      177.7    54  48.0    52     51.0
# 2018-05-23      177.7    63  51.0    55     57.0
# 2018-05-24      177.7    71  55.0    68     63.0
# 2018-05-25      177.7    87  68.0    72     77.5
# 2018-05-26      177.7    87  68.0    72     77.5
# 2018-05-27      177.7    87  68.0    72     77.5
# 2018-05-28      177.7    87  68.0    72     77.5
# 2018-05-29      177.7    87  68.0    72     77.5
# 2018-05-30      177.7    77  68.0    73      NaN
# 2018-05-31      177.7    88  67.0    67     77.5

# %% [markdown]
# Let's use .loc to get the data record we want (as suggested by the previous warning message)

# %%
weather2018.loc['2018-05-30']
# Out:
# STATION                          USC00111550
# NAME         CHICAGO NORTHERLY ISLAND, IL US
# LATITUDE                             41.8558
# LONGITUDE                           -87.6094
# ELEVATION                              177.7
# TMAX                                      77
# TMIN                                    68.0
# TOBS                                      73
# Name: 2018-05-30 00:00:00, dtype: object

# %%
#Filling the missing values 
#weather2018.medianT.fillna(method='ffill',inplace=True)

# %%
#weather2018.loc['2018-05-30']

# %%
medianTemp0530=((weather2018.loc['2018-05-30'].TMAX + weather2018.loc['2018-05-30'].TMIN)/2)
medianTemp0530
# Out:
# 72.5

# %%
weather2018.loc['2018-05-30','medianT'] =medianTemp0530

# %% [markdown]
# The value assignment operation in the previous cell did not work and prompted a warning. To understand this and explore further, look at:  https://www.dataquest.io/blog/settingwithcopywarning/

# %%
#Value assignment did not work 
weather2018.loc['2018-05-30']
# Out:
# STATION                          USC00111550
# NAME         CHICAGO NORTHERLY ISLAND, IL US
# LATITUDE                             41.8558
# LONGITUDE                           -87.6094
# ELEVATION                              177.7
# TMAX                                      77
# TMIN                                    68.0
# TOBS                                      73
# medianT                                 72.5
# Name: 2018-05-30 00:00:00, dtype: object

# %%
#correct assignment
weather2018.loc['2018-05-30','medianT']=medianTemp0530

# %%
weather2018.loc['2018-05-30']
# Out:
# STATION                          USC00111550
# NAME         CHICAGO NORTHERLY ISLAND, IL US
# LATITUDE                             41.8558
# LONGITUDE                           -87.6094
# ELEVATION                              177.7
# TMAX                                      77
# TMIN                                    68.0
# TOBS                                      73
# medianT                                 72.5
# Name: 2018-05-30 00:00:00, dtype: object

# %%
weather2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2018-01-01 to 2018-12-31
# Freq: D
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    365 non-null    object
#  1   NAME       365 non-null    object
#  2   LATITUDE   365 non-null    float64
#  3   LONGITUDE  365 non-null    float64
#  4   ELEVATION  365 non-null    float64
#  5   TMAX       365 non-null    int64
#  6   TMIN       365 non-null    float64
#  7   TOBS       365 non-null    int64
#  8   medianT    1 non-null      float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 36.6+ KB

# %% [markdown]
# ## Plots

# %%
weather2018.medianT.plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# Let's plot the crime and weather together

# %%
daily_temp2018=weather2018.medianT

# %%
daily_temp2018.plot()
daily_crimes2018.plot()
plt.legend()

# %% [markdown]
# Better make separate plots (use subplots)

# %%
figsize = (8,3)
plt.figure()
daily_temp2018.plot(title='Temperature', figsize=figsize)
plt.ylabel('Median daily temperature (F)')
plt.figure()
daily_crimes2018.plot(title='Crimes', figsize=figsize)
plt.ylabel('Crimes count per day')
plt.show()

# %% [markdown]
# Let's smooth the plots by using a "rolling" mean.\
# rolling(X).mean() = compute the mean over the last X samples

# %%
daily_crimes2018.rolling(10).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Let's build a slider widget to better control the smoothing

# %%
from ipywidgets import interact, widgets

@interact(periods=widgets.IntSlider(min=10,max=100,step=10,value=50))
def plot_moving_average(periods=50):
    figsize = (8,3)
    plt.figure()
    daily_temp2018.rolling(periods).mean().plot(title='Temperature', figsize=figsize)
    plt.ylabel('Average daily temperature')
    plt.figure()
    daily_crimes2018.rolling(periods).mean().plot(title='Crimes', figsize=figsize)
    plt.ylabel('Crimes count per day')
    plt.show()
# Out:
# interactive(children=(IntSlider(value=50, description='periods', min=10, step=10), Output()), _dom_classes=('w…

# %% [markdown]
# ## Computing correlations

# %%
combined2018 = pd.DataFrame({'crimes': daily_crimes2018, 'temperature': daily_temp2018})
combined2018.head()
# Out:
#             crimes  temperature
# 2018-01-01     925          0.5
# 2018-01-02     560          0.5
# 2018-01-03     574         13.0
# 2018-01-04     602          9.0
# 2018-01-05     664          8.0

# %% [markdown]
# Scatter plot

# %%
combined2018.plot(kind='scatter', x='temperature', y='crimes')
# Out:
# <Axes: xlabel='temperature', ylabel='crimes'>

# %% [markdown]
# There is some correlation. Let's compute it

# %%
combined2018.corr() # Pearson correlation by default – the standard correlation coefficient
# Out:
#                crimes  temperature
# crimes       1.000000     0.731254
# temperature  0.731254     1.000000

# %% [markdown]
# Let's look at the outliers

# %%
combined2018[combined2018.crimes > 950]
# Out:
#             crimes  temperature
# 2018-05-01    1006         71.0
# 2018-06-01    1009         63.0
# 2018-07-01     976         84.0
# 2018-09-01     980         78.5

# %% [markdown]
# ## Correlation matrix

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 946893 entries, 2018-09-01 00:01:00 to 2021-10-01 10:00:00
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    946893 non-null  int64
#  1   Case Number           946893 non-null  object
#  2   Block                 946893 non-null  object
#  3   IUCR                  946893 non-null  object
#  4   Primary Type          946893 non-null  object
#  5   Description           946893 non-null  object
#  6   Location Description  942727 non-null  object
#  7   Arrest                946893 non-null  bool
#  8   Domestic              946893 non-null  bool
#  9   Beat                  946893 non-null  int64
#  10  District              946893 non-null  int64
#  11  Ward                  946854 non-null  float64
#  12  Community Area        946892 non-null  float64
#  13  FBI Code              946893 non-null  object
#  14  X Coordinate          934034 non-null  float64
#  15  Y Coordinate          934034 non-null  float64
#  16  Year                  946893 non-null  int64
#  17  Updated On            946893 non-null  object
#  18  Latitude              934034 non-null  float64
#  19  Longitude             934034 non-null  float64
#  20  Location              934034 non-null  object
# dtypes: bool(2), float64(6), int64(4), object(9)
# memory usage: 146.3+ MB

# %%
#Just process the 2018 data
crimes2018=crimes.loc['2018']

# %% [markdown]
# Group crimes by type, count the occurrences per day so that later we can generate a column based organization of the data (i.e. split the counts into different columns where each columm corresponds to crime type)

# %%
crimesB = crimes2018.set_index(['Primary Type'], append=True)
crimesB['ocurrences'] = np.ones(len(crimesB), dtype=int)  #adding a new column (of just ones) to facilitate counting 
crimesB.head()
# Out:
#                                               ID Case Number  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT               11646166    JC213529
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE  11645648    JC212959
# 2018-12-20 16:00:00 OTHER OFFENSE       11645959    JC211511
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE  11645557    JC212685
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE  11646293    JC213749
#
#                                                         Block  IUCR  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT               082XX S INGLESIDE AVE   810
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE    024XX N MONITOR AVE  1153
# 2018-12-20 16:00:00 OTHER OFFENSE          045XX N ALBANY AVE  2820
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE     080XX S VERNON AVE  1153
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE   023XX N LOCKWOOD AVE  1154
#
#                                                                     Description  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT                                             OVER $500
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-12-20 16:00:00 OTHER OFFENSE                              TELEPHONE THREAT
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#                                        Location Description  Arrest  Domestic  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT                         RESIDENCE   False      True
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE            RESIDENCE   False     False
# 2018-12-20 16:00:00 OTHER OFFENSE                 RESIDENCE   False     False
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE            RESIDENCE   False     False
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE            APARTMENT   False     False
#
#                                         Beat  District  ...  Community Area  \
# Date                Primary Type                        ...
# 2018-09-01 00:01:00 THEFT                631         6  ...            44.0
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE  2515        25  ...            19.0
# 2018-12-20 16:00:00 OTHER OFFENSE       1724        17  ...            14.0
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE   631         6  ...            44.0
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE  2515        25  ...            19.0
#
#                                         FBI Code X Coordinate  Y Coordinate  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT                      6          NaN           NaN
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE        11          NaN           NaN
# 2018-12-20 16:00:00 OTHER OFFENSE            08A          NaN           NaN
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE        11          NaN           NaN
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE        11          NaN           NaN
#
#                                         Year      Updated On Latitude  \
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT               2018  4/6/2019 16:04      NaN
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE  2018  4/6/2019 16:04      NaN
# 2018-12-20 16:00:00 OTHER OFFENSE       2018  4/6/2019 16:04      NaN
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE  2018  4/6/2019 16:04      NaN
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE  2018  4/6/2019 16:04      NaN
#
#                                         Longitude  Location ocurrences
# Date                Primary Type
# 2018-09-01 00:01:00 THEFT                     NaN       NaN          1
# 2018-01-01 08:00:00 DECEPTIVE PRACTICE        NaN       NaN          1
# 2018-12-20 16:00:00 OTHER OFFENSE             NaN       NaN          1
# 2018-04-01 00:01:00 DECEPTIVE PRACTICE        NaN       NaN          1
# 2018-12-20 15:00:00 DECEPTIVE PRACTICE        NaN       NaN          1
#
# [5 rows x 21 columns]

# %%
crimes_grouped = crimesB.ocurrences.groupby(level=[0,1]).sum()
crimes_grouped
# Out:
# Date                 Primary Type
# 2018-01-01 00:00:00  ASSAULT                2
#                      BATTERY                5
#                      BURGLARY               1
#                      CRIM SEXUAL ASSAULT    5
#                      CRIMINAL DAMAGE        3
#                                            ..
# 2018-12-31 23:55:00  BATTERY                1
# 2018-12-31 23:56:00  BATTERY                1
# 2018-12-31 23:57:00  CRIMINAL DAMAGE        1
# 2018-12-31 23:59:00  CRIMINAL DAMAGE        1
#                      DECEPTIVE PRACTICE     1
# Name: ocurrences, Length: 207477, dtype: int64

# %% [markdown]
# Splitting the data into a column based display (unstacking)

# %%
#crimes_by_type = crimes_grouped.unstack(level=1).fillna(0).resample('D').sum()
crimes_by_type = crimes_grouped.unstack(level=1).fillna(0).resample('D').sum().astype(int)
crimes_by_type.head()
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Date
# 2018-01-01        0       38      161        32
# 2018-01-02        0       28       89        20
# 2018-01-03        1       39       81        19
# 2018-01-04        2       42      102        31
# 2018-01-05        0       53      107        24
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Date
# 2018-01-01                                    0                   13
# 2018-01-02                                    0                    2
# 2018-01-03                                    0                    3
# 2018-01-04                                    0                    0
# 2018-01-05                                    0                    3
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  \
# Date
# 2018-01-01                 66                        9                 10
# 2018-01-02                 46                        0                 17
# 2018-01-03                 38                        0                 17
# 2018-01-04                 47                        0                 23
# 2018-01-05                 63                        1                 16
#
# Primary Type  DECEPTIVE PRACTICE  ...  OTHER NARCOTIC VIOLATION  \
# Date                              ...
# 2018-01-01                   114  ...                         0
# 2018-01-02                    61  ...                         0
# 2018-01-03                    55  ...                         0
# 2018-01-04                    48  ...                         0
# 2018-01-05                    60  ...                         0
#
# Primary Type  OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# Date
# 2018-01-01               64             0                 0
# 2018-01-02               49             0                 0
# 2018-01-03               39             3                 0
# 2018-01-04               43             0                 0
# 2018-01-05               44             0                 0
#
# Primary Type  PUBLIC PEACE VIOLATION  ROBBERY  SEX OFFENSE  STALKING  THEFT  \
# Date
# 2018-01-01                         2       30           36         1    132
# 2018-01-02                         3       28            0         1    128
# 2018-01-03                         3       37            0         0    159
# 2018-01-04                         2       32            0         1    134
# 2018-01-05                         1       34            2         0    164
#
# Primary Type  WEAPONS VIOLATION
# Date
# 2018-01-01                   20
# 2018-01-02                    9
# 2018-01-03                   12
# 2018-01-04                   15
# 2018-01-05                    9
#
# [5 rows x 33 columns]

# %%
crimes_detail2018 = crimes_by_type
crimes_detail2018['temperature'] = daily_temp2018
crimes_detail2018.tail()
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Date
# 2018-12-27        0       43       92        35
# 2018-12-28        0       46      119        33
# 2018-12-29        2       50      142        35
# 2018-12-30        0       47      139        34
# 2018-12-31        1       42      106        29
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Date
# 2018-12-27                                    0                    1
# 2018-12-28                                    0                    3
# 2018-12-29                                    1                    3
# 2018-12-30                                    0                    4
# 2018-12-31                                    1                    2
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  \
# Date
# 2018-12-27                 67                        0                 14
# 2018-12-28                 64                        1                 16
# 2018-12-29                 85                        0                 19
# 2018-12-30                 86                        1                 15
# 2018-12-31                 94                        2                 14
#
# Primary Type  DECEPTIVE PRACTICE  ...  OTHER OFFENSE  PROSTITUTION  \
# Date                              ...
# 2018-12-27                    45  ...             36             5
# 2018-12-28                    55  ...             37             3
# 2018-12-29                    40  ...             41             0
# 2018-12-30                    38  ...             37             0
# 2018-12-31                    46  ...             29             0
#
# Primary Type  PUBLIC INDECENCY  PUBLIC PEACE VIOLATION  ROBBERY  SEX OFFENSE  \
# Date
# 2018-12-27                   0                       3       27            2
# 2018-12-28                   0                       6       38            2
# 2018-12-29                   0                       3       30            1
# 2018-12-30                   0                       3       38            1
# 2018-12-31                   0                       3       40            0
#
# Primary Type  STALKING  THEFT  WEAPONS VIOLATION  temperature
# Date
# 2018-12-27           0    171                 19         45.0
# 2018-12-28           2    187                 20         41.5
# 2018-12-29           0    145                 21         27.5
# 2018-12-30           0    142                 16         29.0
# 2018-12-31           0    160                 21         36.5
#
# [5 rows x 34 columns]

# %%
corr = crimes_detail2018.corr()
corr.style.background_gradient()   #the higher the correlation value, the darker the color
# Out:
# <style type="text/css">
# #T_f59c3_row0_col0, #T_f59c3_row1_col1, #T_f59c3_row2_col2, #T_f59c3_row3_col3, #T_f59c3_row4_col4, #T_f59c3_row5_col5, #T_f59c3_row6_col6, #T_f59c3_row7_col7, #T_f59c3_row8_col8, #T_f59c3_row9_col9, #T_f59c3_row10_col10, #T_f59c3_row11_col11, #T_f59c3_row12_col12, #T_f59c3_row13_col13, #T_f59c3_row14_col14, #T_f59c3_row15_col15, #T_f59c3_row16_col16, #T_f59c3_row17_col17, #T_f59c3_row18_col18, #T_f59c3_row19_col19, #T_f59c3_row20_col20, #T_f59c3_row21_col21, #T_f59c3_row22_col22, #T_f59c3_row23_col23, #T_f59c3_row24_col24, #T_f59c3_row25_col25, #T_f59c3_row26_col26, #T_f59c3_row27_col27, #T_f59c3_row28_col28, #T_f59c3_row29_col29, #T_f59c3_row30_col30, #T_f59c3_row31_col31, #T_f59c3_row32_col32, #T_f59c3_row33_col33 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f59c3_row0_col1, #T_f59c3_row3_col19, #T_f59c3_row5_col11, #T_f59c3_row12_col9, #T_f59c3_row17_col32, #T_f59c3_row21_col29, #T_f59c3_row26_col2, #T_f59c3_row29_col33, #T_f59c3_row31_col5, #T_f59c3_row32_col17 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_f59c3_row0_col2, #T_f59c3_row1_col27, #T_f59c3_row3_col17, #T_f59c3_row6_col5, #T_f59c3_row6_col16, #T_f59c3_row9_col18, #T_f59c3_row32_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_f59c3_row0_col3, #T_f59c3_row1_col30, #T_f59c3_row3_col16, #T_f59c3_row4_col26, #T_f59c3_row6_col29, #T_f59c3_row8_col30, #T_f59c3_row9_col14, #T_f59c3_row10_col15, #T_f59c3_row10_col18, #T_f59c3_row11_col0, #T_f59c3_row11_col1, #T_f59c3_row11_col13, #T_f59c3_row13_col16, #T_f59c3_row14_col6, #T_f59c3_row15_col9, #T_f59c3_row16_col14, #T_f59c3_row17_col0, #T_f59c3_row18_col28, #T_f59c3_row20_col9, #T_f59c3_row21_col6, #T_f59c3_row21_col18, #T_f59c3_row22_col30, #T_f59c3_row25_col3, #T_f59c3_row25_col13, #T_f59c3_row26_col33, #T_f59c3_row27_col31, #T_f59c3_row29_col14, #T_f59c3_row29_col20, #T_f59c3_row30_col10, #T_f59c3_row33_col25 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_f59c3_row0_col4, #T_f59c3_row0_col7, #T_f59c3_row0_col9, #T_f59c3_row0_col26, #T_f59c3_row0_col29, #T_f59c3_row1_col12, #T_f59c3_row2_col8, #T_f59c3_row4_col3, #T_f59c3_row6_col17, #T_f59c3_row8_col16, #T_f59c3_row8_col20, #T_f59c3_row10_col7, #T_f59c3_row11_col12, #T_f59c3_row12_col0, #T_f59c3_row13_col0, #T_f59c3_row13_col14, #T_f59c3_row14_col8, #T_f59c3_row14_col17, #T_f59c3_row14_col26, #T_f59c3_row14_col32, #T_f59c3_row17_col13, #T_f59c3_row17_col15, #T_f59c3_row20_col17, #T_f59c3_row20_col19, #T_f59c3_row20_col23, #T_f59c3_row20_col31, #T_f59c3_row21_col7, #T_f59c3_row22_col1, #T_f59c3_row22_col20, #T_f59c3_row22_col27, #T_f59c3_row23_col8, #T_f59c3_row23_col25, #T_f59c3_row26_col5, #T_f59c3_row27_col22, #T_f59c3_row27_col29, #T_f59c3_row28_col23, #T_f59c3_row28_col25, #T_f59c3_row30_col27, #T_f59c3_row33_col12 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_f59c3_row0_col5, #T_f59c3_row3_col7, #T_f59c3_row3_col30, #T_f59c3_row4_col5, #T_f59c3_row4_col9, #T_f59c3_row5_col3, #T_f59c3_row6_col22, #T_f59c3_row7_col19, #T_f59c3_row8_col14, #T_f59c3_row10_col11, #T_f59c3_row10_col17, #T_f59c3_row10_col19, #T_f59c3_row12_col14, #T_f59c3_row12_col16, #T_f59c3_row12_col17, #T_f59c3_row12_col29, #T_f59c3_row13_col15, #T_f59c3_row14_col3, #T_f59c3_row14_col10, #T_f59c3_row14_col20, #T_f59c3_row15_col12, #T_f59c3_row16_col17, #T_f59c3_row16_col24, #T_f59c3_row17_col20, #T_f59c3_row17_col21, #T_f59c3_row18_col19, #T_f59c3_row19_col0, #T_f59c3_row20_col1, #T_f59c3_row20_col15, #T_f59c3_row23_col2, #T_f59c3_row23_col6, #T_f59c3_row23_col9, #T_f59c3_row25_col10, #T_f59c3_row25_col28, #T_f59c3_row26_col10, #T_f59c3_row26_col32, #T_f59c3_row28_col1, #T_f59c3_row28_col13, #T_f59c3_row28_col14, #T_f59c3_row28_col15, #T_f59c3_row28_col24, #T_f59c3_row28_col29, #T_f59c3_row29_col13, #T_f59c3_row29_col15, #T_f59c3_row32_col12, #T_f59c3_row32_col14 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_f59c3_row0_col6, #T_f59c3_row2_col11, #T_f59c3_row3_col0, #T_f59c3_row3_col21, #T_f59c3_row8_col33, #T_f59c3_row16_col33, #T_f59c3_row22_col2, #T_f59c3_row27_col9, #T_f59c3_row31_col8, #T_f59c3_row31_col25 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_f59c3_row0_col8, #T_f59c3_row2_col25, #T_f59c3_row5_col19, #T_f59c3_row5_col20, #T_f59c3_row7_col1, #T_f59c3_row8_col23, #T_f59c3_row9_col11, #T_f59c3_row9_col26, #T_f59c3_row11_col8, #T_f59c3_row12_col23, #T_f59c3_row12_col26, #T_f59c3_row13_col22, #T_f59c3_row15_col28, #T_f59c3_row19_col21, #T_f59c3_row19_col33, #T_f59c3_row21_col16, #T_f59c3_row21_col27, #T_f59c3_row22_col4, #T_f59c3_row22_col23, #T_f59c3_row23_col0, #T_f59c3_row23_col5, #T_f59c3_row24_col4, #T_f59c3_row24_col14, #T_f59c3_row25_col4, #T_f59c3_row26_col12, #T_f59c3_row26_col23, #T_f59c3_row26_col28, #T_f59c3_row26_col29, #T_f59c3_row26_col30, #T_f59c3_row27_col10, #T_f59c3_row28_col27, #T_f59c3_row33_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_f59c3_row0_col10, #T_f59c3_row1_col4, #T_f59c3_row4_col17, #T_f59c3_row5_col26, #T_f59c3_row7_col18, #T_f59c3_row7_col20, #T_f59c3_row7_col26, #T_f59c3_row7_col33, #T_f59c3_row11_col7, #T_f59c3_row11_col19, #T_f59c3_row12_col22, #T_f59c3_row12_col32, #T_f59c3_row14_col12, #T_f59c3_row15_col22, #T_f59c3_row15_col26, #T_f59c3_row15_col27, #T_f59c3_row17_col10, #T_f59c3_row17_col14, #T_f59c3_row19_col2, #T_f59c3_row19_col20, #T_f59c3_row19_col24, #T_f59c3_row21_col8, #T_f59c3_row21_col26, #T_f59c3_row23_col12, #T_f59c3_row23_col26, #T_f59c3_row24_col19, #T_f59c3_row24_col23, #T_f59c3_row24_col28, #T_f59c3_row27_col19, #T_f59c3_row28_col12, #T_f59c3_row29_col18, #T_f59c3_row29_col26, #T_f59c3_row30_col32, #T_f59c3_row31_col22 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_f59c3_row0_col11, #T_f59c3_row3_col15, #T_f59c3_row4_col0, #T_f59c3_row4_col11, #T_f59c3_row7_col15, #T_f59c3_row8_col6, #T_f59c3_row8_col21, #T_f59c3_row11_col25, #T_f59c3_row12_col8, #T_f59c3_row13_col9, #T_f59c3_row13_col29, #T_f59c3_row14_col23, #T_f59c3_row16_col20, #T_f59c3_row23_col20, #T_f59c3_row26_col1, #T_f59c3_row26_col9, #T_f59c3_row26_col15, #T_f59c3_row29_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_f59c3_row0_col12, #T_f59c3_row3_col12, #T_f59c3_row4_col14, #T_f59c3_row5_col23, #T_f59c3_row9_col25, #T_f59c3_row11_col27, #T_f59c3_row12_col33, #T_f59c3_row14_col7, #T_f59c3_row15_col3, #T_f59c3_row15_col13, #T_f59c3_row15_col29, #T_f59c3_row17_col19, #T_f59c3_row18_col17, #T_f59c3_row18_col22, #T_f59c3_row19_col5, #T_f59c3_row19_col13, #T_f59c3_row21_col19, #T_f59c3_row25_col17, #T_f59c3_row29_col8, #T_f59c3_row29_col19, #T_f59c3_row30_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_f59c3_row0_col13, #T_f59c3_row8_col7, #T_f59c3_row15_col25, #T_f59c3_row18_col7, #T_f59c3_row20_col7, #T_f59c3_row21_col14, #T_f59c3_row22_col8, #T_f59c3_row27_col11, #T_f59c3_row30_col16, #T_f59c3_row33_col23 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_f59c3_row0_col14, #T_f59c3_row17_col9, #T_f59c3_row31_col0, #T_f59c3_row31_col14 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_f59c3_row0_col15, #T_f59c3_row5_col14, #T_f59c3_row10_col23, #T_f59c3_row12_col25, #T_f59c3_row12_col31, #T_f59c3_row16_col21, #T_f59c3_row19_col12, #T_f59c3_row19_col17, #T_f59c3_row20_col22, #T_f59c3_row20_col28, #T_f59c3_row22_col19, #T_f59c3_row22_col25, #T_f59c3_row23_col4, #T_f59c3_row27_col7, #T_f59c3_row30_col26, #T_f59c3_row30_col31 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_f59c3_row0_col16, #T_f59c3_row1_col28, #T_f59c3_row2_col20, #T_f59c3_row2_col21, #T_f59c3_row3_col26, #T_f59c3_row4_col31, #T_f59c3_row5_col13, #T_f59c3_row7_col3, #T_f59c3_row7_col21, #T_f59c3_row8_col32, #T_f59c3_row11_col3, #T_f59c3_row11_col10, #T_f59c3_row13_col28, #T_f59c3_row15_col14, #T_f59c3_row15_col31, #T_f59c3_row16_col0, #T_f59c3_row16_col3, #T_f59c3_row16_col7, #T_f59c3_row16_col13, #T_f59c3_row16_col22, #T_f59c3_row17_col11, #T_f59c3_row17_col23, #T_f59c3_row18_col5, #T_f59c3_row19_col18, #T_f59c3_row20_col21, #T_f59c3_row22_col15, #T_f59c3_row25_col8, #T_f59c3_row26_col19, #T_f59c3

# %% [markdown]
# Let's focus on the correlation with temperature

# %%
corr = crimes_detail2018.corr().loc[:,['temperature']].sort_values(ascending=False, by='temperature')
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_a438e_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a438e_row1_col0 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_a438e_row2_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_a438e_row3_col0 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_a438e_row4_col0 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_a438e_row5_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a438e_row6_col0 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_a438e_row7_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_a438e_row8_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_a438e_row9_col0, #T_a438e_row10_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_a438e_row11_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_a438e_row12_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_a438e_row13_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_a438e_row14_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_a438e_row15_col0, #T_a438e_row16_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a438e_row17_col0, #T_a438e_row18_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_a438e_row19_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_a438e_row20_col0, #T_a438e_row21_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a438e_row22_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a438e_row23_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_a438e_row24_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_a438e_row25_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_a438e_row26_col0, #T_a438e_row27_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a438e_row28_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_a438e_row29_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_a438e_row30_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a438e_row31_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_a438e_row32_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a438e_row33_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a438e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Primary Type</th>
#       <th id="T_a438e_level0_col0" class="col_heading level0 col0" >temperature</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Primary Type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a438e_level0_row0" class="row_heading level0 row0" >temperature</th>
#       <td id="T_a438e_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row1" class="row_heading level0 row1" >THEFT</th>
#       <td id="T_a438e_row1_col0" class="data row1 col0" >0.631531</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row2" class="row_heading level0 row2" >ASSAULT</th>
#       <td id="T_a438e_row2_col0" class="data row2 col0" >0.602843</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row3" class="row_heading level0 row3" >BATTERY</th>
#       <td id="T_a438e_row3_col0" class="data row3 col0" >0.583445</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row4" class="row_heading level0 row4" >CRIMINAL DAMAGE</th>
#       <td id="T_a438e_row4_col0" class="data row4 col0" >0.567045</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row5" class="row_heading level0 row5" >GAMBLING</th>
#       <td id="T_a438e_row5_col0" class="data row5 col0" >0.427726</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row6" class="row_heading level0 row6" >BURGLARY</th>
#       <td id="T_a438e_row6_col0" class="data row6 col0" >0.424042</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row7" class="row_heading level0 row7" >WEAPONS VIOLATION</th>
#       <td id="T_a438e_row7_col0" class="data row7 col0" >0.419322</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row8" class="row_heading level0 row8" >INTERFERENCE WITH PUBLIC OFFICER</th>
#       <td id="T_a438e_row8_col0" class="data row8 col0" >0.234233</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row9" class="row_heading level0 row9" >CRIM SEXUAL ASSAULT</th>
#       <td id="T_a438e_row9_col0" class="data row9 col0" >0.203879</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row10" class="row_heading level0 row10" >OTHER OFFENSE</th>
#       <td id="T_a438e_row10_col0" class="data row10 col0" >0.200749</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row11" class="row_heading level0 row11" >ROBBERY</th>
#       <td id="T_a438e_row11_col0" class="data row11 col0" >0.199001</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row12" class="row_heading level0 row12" >HOMICIDE</th>
#       <td id="T_a438e_row12_col0" class="data row12 col0" >0.170503</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row13" class="row_heading level0 row13" >CONCEALED CARRY LICENSE VIOLATION</th>
#       <td id="T_a438e_row13_col0" class="data row13 col0" >0.161444</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row14" class="row_heading level0 row14" >INTIMIDATION</th>
#       <td id="T_a438e_row14_col0" class="data row14 col0" >0.147765</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row15" class="row_heading level0 row15" >CRIMINAL TRESPASS</th>
#       <td id="T_a438e_row15_col0" class="data row15 col0" >0.141437</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row16" class="row_heading level0 row16" >LIQUOR LAW VIOLATION</th>
#       <td id="T_a438e_row16_col0" class="data row16 col0" >0.138300</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row17" class="row_heading level0 row17" >NARCOTICS</th>
#       <td id="T_a438e_row17_col0" class="data row17 col0" >0.137281</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row18" class="row_heading level0 row18" >ARSON</th>
#       <td id="T_a438e_row18_col0" class="data row18 col0" >0.135807</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row19" class="row_heading level0 row19" >SEX OFFENSE</th>
#       <td id="T_a438e_row19_col0" class="data row19 col0" >0.129457</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row20" class="row_heading level0 row20" >PROSTITUTION</th>
#       <td id="T_a438e_row20_col0" class="data row20 col0" >0.123204</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row21" class="row_heading level0 row21" >PUBLIC PEACE VIOLATION</th>
#       <td id="T_a438e_row21_col0" class="data row21 col0" >0.121786</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row22" class="row_heading level0 row22" >PUBLIC INDECENCY</th>
#       <td id="T_a438e_row22_col0" class="data row22 col0" >0.092244</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row23" class="row_heading level0 row23" >DECEPTIVE PRACTICE</th>
#       <td id="T_a438e_row23_col0" class="data row23 col0" >0.080289</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row24" class="row_heading level0 row24" >OBSCENITY</th>
#       <td id="T_a438e_row24_col0" class="data row24 col0" >0.052042</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row25" class="row_heading level0 row25" >NON-CRIMINAL (SUBJECT SPECIFIED)</th>
#       <td id="T_a438e_row25_col0" class="data row25 col0" >0.036180</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row26" class="row_heading level0 row26" >STALKING</th>
#       <td id="T_a438e_row26_col0" class="data row26 col0" >0.019735</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row27" class="row_heading level0 row27" >KIDNAPPING</th>
#       <td id="T_a438e_row27_col0" class="data row27 col0" >0.016956</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row28" class="row_heading level0 row28" >CRIMINAL SEXUAL ASSAULT</th>
#       <td id="T_a438e_row28_col0" class="data row28 col0" >0.010836</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row29" class="row_heading level0 row29" >MOTOR VEHICLE THEFT</th>
#       <td id="T_a438e_row29_col0" class="data row29 col0" >-0.002366</td>
#     </tr>
#     <tr>
#       <th id="T_a438e_level0_row30" class="

# %% [markdown]
# Let's check on the amount of data for each crime type

# %%
crimes_by_type.sum().sort_values(ascending=False)
# Out:
# Primary Type
# THEFT                                65268.0
# BATTERY                              49813.0
# CRIMINAL DAMAGE                      27823.0
# ASSAULT                              20403.0
# DECEPTIVE PRACTICE                   19590.0
# temperature                          18390.5
# OTHER OFFENSE                        17253.0
# NARCOTICS                            13577.0
# BURGLARY                             11745.0
# MOTOR VEHICLE THEFT                   9982.0
# ROBBERY                               9679.0
# CRIMINAL TRESPASS                     6907.0
# WEAPONS VIOLATION                     5456.0
# OFFENSE INVOLVING CHILDREN            2311.0
# CRIM SEXUAL ASSAULT                   1449.0
# PUBLIC PEACE VIOLATION                1372.0
# INTERFERENCE WITH PUBLIC OFFICER      1306.0
# SEX OFFENSE                           1155.0
# PROSTITUTION                           718.0
# HOMICIDE                               600.0
# ARSON                                  373.0
# LIQUOR LAW VIOLATION                   268.0
# CRIMINAL SEXUAL ASSAULT                225.0
# STALKING                               207.0
# GAMBLING                               201.0
# KIDNAPPING                             172.0
# INTIMIDATION                           169.0
# CONCEALED CARRY LICENSE VIOLATION      149.0
# OBSCENITY                               87.0
# NON-CRIMINAL                            36.0
# PUBLIC INDECENCY                        14.0
# HUMAN TRAFFICKING                       12.0
# NON-CRIMINAL (SUBJECT SPECIFIED)         3.0
# OTHER NARCOTIC VIOLATION                 1.0
# dtype: float64
